# %% [markdown]
# # Pre-trained GPT-2 Notebook
#
# <a target="_blank" href="https://colab.research.google.com/github/simonguest/CS-394/blob/main/src/01/notebooks/GPT-2.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
# <a target="_blank" href="https://github.com/simonguest/CS-394/raw/refs/heads/main/src/01/notebooks/GPT-2.ipynb">
#   <img src="https://img.shields.io/badge/Download_.ipynb-blue" alt="Download .ipynb"/>
# </a>

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load pre-trained GPT-2 model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# Set pad token
tokenizer.pad_token = tokenizer.eos_token
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
import torch

def autocomplete(prompt, max_length=50, temperature=0.7, top_k=50, top_p=0.9, is_sampling = True):
    # Encode the prompt with attention mask
    inputs = tokenizer(prompt, return_tensors="pt")

    # Generate continuation
    with torch.no_grad():
        output = model.generate(
            inputs['input_ids'],
            attention_mask=inputs['attention_mask'],
            max_length=max_length,
            temperature=temperature,
            top_k=top_k,
            top_p=top_p,
            do_sample=is_sampling,
            pad_token_id=tokenizer.eos_token_id
        )

    # Decode and return the generated text
    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
    return generated_text

# %% [markdown]
# Create 3 different story starters in different genres/styles. For example:
# *   Fantasy/Adventure: “In a land of dragons and magic…”
# *   Sci-fi: “The year is 2157. Humanity has just…”
# *   Mystery: “The detective examined the crime scene and noticed…”
# *   (or choose your own three)
#
# Then adjust for:
# *   Greedy decoding vs. sampling
# *   Different temperature values
# *   How the opening sentence shapes the continuation (e.g., short vs. long)
#
# Document your observations (using Markdown in the notebook)
# *   What differences do you notice between the strategies?
# *   What worked well (or surprised you!)
# *  What didn’t work that well

# %%
prompts = [
    "Gandalf is a wizard that is about to go on a journey to Hogwarts",
    "Ju-ve built a time machine, and went back in time 27 years ago",
    "Professor Dimitar Volpermort is kidnapped at DigiPen Institute of Technology",
    "Willaim is in love with Juliet"
]

for prompt in prompts:
    print(f"\nPrompt: {prompt}")
    print("-" * 50)
    completion = autocomplete(prompt, max_length=80, is_sampling = False)
    print(f"Greedy Output: {completion}\n")
    print("-" * 50)
    completion = autocomplete(prompt, max_length=80)
    print(f"Sampling Output: {completion}\n")
    print("-" * 50)
    completion = autocomplete(prompt, max_length=80, temperature=1.0)
    print(f"Sampling w/ 1.0 temperature Output: {completion}\n")
    print("-" * 50)
    completion = autocomplete(prompt, max_length=80, temperature=1.5)
    print(f"Sampling w/ 1.5 temperature Output: {completion}\n")
    print("-" * 50)
    completion = autocomplete(prompt, max_length=160, temperature=1.5)
    print(f"Sampling w/ 1.5 temperature and 160 max Output: {completion}\n")
# Out:
# Prompt: Gandalf is a wizard that is about to go on a journey to Hogwarts
# --------------------------------------------------
# Greedy Output: Gandalf is a wizard that is about to go on a journey to Hogwarts. He is a wizard who has been trained by the wizarding world to be a wizard. He is a wizard who has been trained by the wizarding world to be a wizard. He is a wizard who has been trained by the wizarding world to be a wizard. He is a wizard who has been trained by
#
# --------------------------------------------------
# Sampling Output: Gandalf is a wizard that is about to go on a journey to Hogwarts to find his father. He is the last of the Death Eaters to be killed in the Battle of Hogwarts, and is the last of the Death Eaters to die in the battle for Hogwarts.
#
# Contents show]
#
# Biography
#
# Early life
#
# Harry Potter, a boy, was born in
#
# --------------------------------------------------
# Sampling w/ 1.0 temperature Output: Gandalf is a wizard that is about to go on a journey to Hogwarts to save his people. However, this isn't what his journey is about. He's been thrown into this evil world to save his family, but when he learns that one of his children is missing, he does not feel the same.
#
# In Wizarding World: Deathly Hallows, he's told that
#
# --------------------------------------------------
# Sampling w/ 1.5 temperature Output: Gandalf is a wizard that is about to go on a journey to Hogwarts, when Hermione arrives at Malfoy Castle: a wizarding house of great fame on one of the magical rivers, Hogwarts. Though there no longer really a name for what is inside these walls, one thinks of Malfoy as being the castle in which Harry and Remus shared common bed in recent memory as they walk through the front
#
# --------------------------------------------------
# Sampling w/ 1.5 temperature and 160 max Output: Gandalf is a wizard that is about to go on a journey to Hogwarts, and he is searching his memories of Harry. He had already given him the information of where Professor Dumbledore was going.
#
# After the news had arrived about Deathly Hallows, Professor McGonagall said her students should take a break. As she stood up with both the school staff and Hermione from her parents' apartment, Ginny's voice was loud.
#
# Hermione's name, which Harry had to guess from that voice, made her stand up from her bunk while McGonagall asked,
#
# "What is it you've found?"
#
# Ginny couldn't take her eyes off of Harry and she felt very sorry for the dead student. McGonagall had put on the veil that protected
#
#
# Prompt: Ju-ve built a time machine, and went back in time 27 years ago
# --------------------------------------------------
# Greedy Output: Ju-ve built a time machine, and went back in time 27 years ago.
#
# The time machine was built by the same company that built the time machine that was used to build the world's longest time machine.
#
# The time machine was built by the same company that built the world's longest time machine.
#
# The time machine was built by the same company that built the world
#
# --------------------------------------------------
# Sampling Output: Ju-ve built a time machine, and went back in time 27 years ago to create the world's first time machine.
#
# "It's a little bit of a surprise that this is the first time that you can take a machine like this to the top of the world," says Chris Prentice, a mechanical engineer at IBM who is also the CEO of the company's robotics division.
#
#
# --------------------------------------------------
# Sampling w/ 1.0 temperature Output: Ju-ve built a time machine, and went back in time 27 years ago, which gave the city an excuse to start building that time machine (I'd argue that has been a great thing).
#
# The city is also building a new pedestrian bridge in the old streetcar lane that can be used for cycling. It's also getting a new street lighting system in place (one that is going to
#
# --------------------------------------------------
# Sampling w/ 1.5 temperature Output: Ju-ve built a time machine, and went back in time 27 years ago.
#
# Here's what happened to me from 1999 through 2002
#
# It has taken me 10 years but the first time my body was affected by this thing was before 2007. I never worked for anyone before this when I worked my way through the last year and still remember thinking: "This thing isn't like me
#
# --------------------------------------------------
# Sampling w/ 1.5 temperature and 160 max Output: Ju-ve built a time machine, and went back in time 27 years ago, in 2006, to present the "Star Trek: The Discovery"-first computer program to the first American film executives in the history of science. I will, of course try and go all-in on the matter further for our Star Trek documentary. (Also, I am curious on The Original Series: how far was the crew before a series called "Apocrypha" was in development)
#
# I don't think much information is being written in relation to that era that we can tell today. It would certainly be interesting. But it is my hope, and my expectation, that the history books will be updated to include an even more complete understanding of Star Trek in a future where information from previous generations has no
#
#
# Prompt: Professor Dimitar Volpermort is kidnapped at DigiPen Institute of Technology
# --------------------------------------------------
# Greedy Output: Professor Dimitar Volpermort is kidnapped at DigiPen Institute of Technology in Moscow. He is later killed by a group of Russian soldiers.
#
# The film is based on the novel by Nikolai Karpov, which was published in the Russian edition of the magazine.
#
# The film is based on the novel by Nikolai Karpov, which was published in the Russian edition of
#
# --------------------------------------------------
# Sampling Output: Professor Dimitar Volpermort is kidnapped at DigiPen Institute of Technology in the Netherlands and brought to a prison where he is forced to use his brain to create a new one.
#
# The brain-enhancing drug is given to him by the head of a team of scientists who have been working on a new way to create brains that can control their own minds. The team has been working
#
# --------------------------------------------------
# Sampling w/ 1.0 temperature Output: Professor Dimitar Volpermort is kidnapped at DigiPen Institute of Technology and brought to the surface. With the help of the crew, they can find the source of the mysterious alien artifact which contains a secret code that is the key to unlocking his mind.
#
# Director: Eric Krasnow
#
# Cast: John Malkovich, Will Arnett, Jason Sudeikis
#
# Original
#
# --------------------------------------------------
# Sampling w/ 1.5 temperature Output: Professor Dimitar Volpermort is kidnapped at DigiPen Institute of Technology in a Moscow train, where three-quarters are in labor. It's a "massive explosion in terms of the number, depth of the work" at his institute, said Volimpils' former director Sergei Parekh. (Sergei Parekh has long supported Volpermort, which became an official center
#
# --------------------------------------------------
# Sampling w/ 1.5 temperature and 160 max Output: Professor Dimitar Volpermort is kidnapped at DigiPen Institute of Technology's annual meeting (May 27, 2017) which begins next week, April 17. Photo, European Pressphoto Agency. Source / Getty Images/European Pressphoto Agency. less Gautam Rajan: Former Defence Minister Gautam (above) told a press conference that it was not impossible to be detained under interrogation regime as long as they stopped talking to us to make us listen for what kind of interrogators will be in the interrogation chamber
#
# An examination by the European Press Council on April 9 showed that during interrogations during 2013 (including those which were also conducted to support the UK Freedom Act), Gautam Rajan was questioned about two of four counts of having ties and connections to terrorism. One was "
#
#
# Prompt: Willaim is in love with Juliet
# --------------------------------------------------
# Greedy Output: Willaim is in love with Juliet, and she's not going to let him down.
#
# The two are in love, and Juliet is going to let him down.
#
# The two are in love, and Juliet is going to let him down.
#
# The two are in love, and Juliet is going to let him down.
#
# The two are in love, and Juliet is
#
# --------------------------------------------------
# Sampling Output: Willaim is in love with Juliet. She's not going to be able to find him. And that's what makes him so great. He's very much a part of the story. And it's a very good story."
#
# Pete and Juliet were married for more than 40 years in New York City. The couple had four children, three of whom were siblings.
#
# "We
#
# --------------------------------------------------
# Sampling w/ 1.0 temperature Output: Willaim is in love with Juliet but he doesn't know how to handle it, even though she knows that he's in love with her. He eventually decides to help her at the end of the book and they move to an apartment that Juliet lives with. In this apartment, Juliet is seen sleeping in the kitchen. She makes her own bed because she loves to stay at home, but as she
#
# --------------------------------------------------
# Sampling w/ 1.5 temperature Output: Willaim is in love with Juliet. The latter says this. It doesn't follow. As it turns out, that's where the kiss ends: they meet up before the death. Their life ends, however.
#
#
# They say that Juliet gave him their second chance. Her life will always be precious to him because of him. They will live their lives on.
#
# —
#
#
# 1
#
# --------------------------------------------------
# Sampling w/ 1.5 temperature and 160 max Output: Willaim is in love with Juliet but they soon see each other when their wedding vows aren't on par. This time their relationship gets to be serious. What did you think when your friends are together in real life when you have so little.
#
# How was your night in The Woods with your lovely wife Julia Roberts last night? What was my mood like. Was I being very careful when telling Julie? The day was awesome and I hope that happens now with her being back here. What went into going ahead for my role as the character. Will those four words be a theme for you during your role. What would you say your character would be about it.
#
# When Julie walks off to visit the woods you get up in one of the tall houses that stand for years before, you

# %% [markdown]
# Document your observations (using Markdown in the notebook)
#
#
#
# 1.   What differences do you notice between the strategies?
# 2.   What worked well (or surprised you!)
# 3.   What didn’t work that well
